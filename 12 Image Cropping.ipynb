# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('images/lenna.png')

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
img_cropped = img[150:301,200:351]

# %%
img_cropped
# Out:
# array([[[120, 123, 208],
#         [125, 118, 211],
#         [115, 115, 211],
#         ...,
#         [167, 175, 213],
#         [167, 186, 223],
#         [169, 186, 231]],
#
#        [[120, 119, 213],
#         [119, 129, 209],
#         [133, 126, 209],
#         ...,
#         [176, 192, 221],
#         [177, 191, 219],
#         [182, 189, 222]],
#
#        [[135, 125, 212],
#         [121, 126, 213],
#         [143, 139, 209],
#         ...,
#         [172, 191, 225],
#         [177, 190, 224],
#         [182, 193, 223]],
#
#        ...,
#
#        [[100,  91, 186],
#         [ 99,  87, 183],
#         [150, 138, 203],
#         ...,
#         [ 65,  29, 115],
#         [ 60,  25, 120],
#         [ 64,  28, 121]],
#
#        [[ 95,  83, 185],
#         [112, 107, 190],
#         [181, 180, 215],
#         ...,
#         [ 67,  29, 123],
#         [ 63,  27, 120],
#         [ 62,  24, 114]],
#
#        [[ 91,  85, 182],
#         [138, 131, 207],
#         [183, 187, 224],
#         ...,
#         [ 64,  24, 118],
#         [ 67,  38, 133],
#         [ 63,  27, 108]]], dtype=uint8)

# %%
cv2.imshow('cropped image:',img_cropped)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img_cropped)

# %%
img_cropped.shape
# Out:
# (151, 151, 3)

# %%
height, width, channels = img.shape

# %%
startRow = int(height*.15)
startCol = int(width*.15)
endRow = int(height*.85)
endCol = int(width*.85)

# %%
img_15p = img[startRow:endRow, startCol:endCol]

# %%
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(img_15p)

# %%
x = np.array([[5,6,7],[1,2,3],[8,0,9]])
y = np.array([[2,5,8],[1,9,0],[3,2,5]])

# %%
x
# Out:
# array([[5, 6, 7],
#        [1, 2, 3],
#        [8, 0, 9]])

# %%
y
# Out:
# array([[2, 5, 8],
#        [1, 9, 0],
#        [3, 2, 5]])

# %%
z= np.hstack([x,y])
z
# Out:
# array([[5, 6, 7, 2, 5, 8],
#        [1, 2, 3, 1, 9, 0],
#        [8, 0, 9, 3, 2, 5]])

# %%
plt.imshow(z)

# %%
# Flip the image horizontally
flipped_horizontal = cv2.flip(img,0)

# %%
new_img = np.hstack([img, flipped_horizontal])

# %%
plt.imshow(new_img)
