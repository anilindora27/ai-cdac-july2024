# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('images/lenna.png')

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
pix = img[300, 200]

# %%
pix
# Out:
# array([ 91,  85, 182], dtype=uint8)

# %%
pix= pix.reshape(1,1,3)
pix
# Out:
# array([[[ 91,  85, 182]]], dtype=uint8)

# %%
plt.imshow(pix)

# %%
cv2.imshow('Image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
for i in range(512):
    img[i,i] = 0

# %%
plt.imshow(img)

# %%
cv2.imshow('Image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img[100:301,100:301] =255

# %%
cv2.imshow('Image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread('images/lenna.png')

# %%
for i in range(0,512,2):
    for j in range(512):
        img[i,j] = 0

# %%
cv2.imshow('Image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
